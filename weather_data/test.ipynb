# %%
from grib_reader import GribXarrayReader

# %%
path = "/Users/gkbrkgrr/Desktop/polymarket-weather-trading/data/raster_data/ecmwf-ensemble/00z/20260106/20260106000000-3h-enfo-ef__params-10u-10v-2r-2t-tp.grib2"

reader = GribXarrayReader()
ds = reader.read_ensemble_params(path, ["t2m", "tp", "u10", "v10"])

# %%
ds.t2m
# Out:
# <xarray.DataArray 't2m' (number: 51, latitude: 721, longitude: 1440)>
# array([[[254.34895, 254.34895, 254.34895, ..., 254.34895, 254.34895,
#          254.34895],
#         [253.6302 , 253.6302 , 253.6302 , ..., 253.6302 , 253.6302 ,
#          253.6302 ],
#         [252.53645, 252.53645, 252.53645, ..., 252.5052 , 252.5052 ,
#          252.53645],
#         ...,
#         [249.59895, 249.59895, 249.6302 , ..., 249.59895, 249.59895,
#          249.59895],
#         [250.03645, 250.03645, 250.03645, ..., 250.03645, 250.03645,
#          250.03645],
#         [250.28645, 250.28645, 250.28645, ..., 250.28645, 250.28645,
#          250.28645]],
#
#        [[253.76753, 253.76753, 253.76753, ..., 253.76753, 253.76753,
#          253.76753],
#         [252.73628, 252.73628, 252.73628, ..., 252.73628, 252.73628,
#          252.73628],
#         [251.58003, 251.58003, 251.58003, ..., 251.54878, 251.54878,
#          251.58003],
# ...
# ...
